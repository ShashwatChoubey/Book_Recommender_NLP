# %%
import pandas as pd
books = pd.read_csv('books_with_categories.csv')

# %%
from transformers import pipeline
pipe = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base",top_k=None)
# Out:
# Device set to use cpu

# %%
pipe("I will never get a gf and die single")
# Out:
# [[{'label': 'sadness', 'score': 0.8042255640029907},
#   {'label': 'anger', 'score': 0.10395780205726624},
#   {'label': 'neutral', 'score': 0.04898032918572426},
#   {'label': 'disgust', 'score': 0.02261645533144474},
#   {'label': 'joy', 'score': 0.010619841516017914},
#   {'label': 'fear', 'score': 0.00816002581268549},
#   {'label': 'surprise', 'score': 0.00143995916005224}]]

# %%
short_desc = books.loc[(books["description"].str.len() < 250) & (books["description"].str.len() > 50)].reset_index()

# %%
sd = short_desc["description"][0]

# %%
sd
# Out:
# '"The Citadel of the Autarch brings The Book of the New sun to its harrowing conclusion, as Severiain clashes in a final reckoning with the dread Autarch, fulfilling an ancient prophesy that will alter forever the realm known as Urth." -- Back cover.'

# %%
pipe(sd)
# Out:
# [[{'label': 'fear', 'score': 0.9862549304962158},
#   {'label': 'sadness', 'score': 0.004601126071065664},
#   {'label': 'neutral', 'score': 0.004379679914563894},
#   {'label': 'disgust', 'score': 0.0013374342815950513},
#   {'label': 'anger', 'score': 0.0011936438968405128},
#   {'label': 'joy', 'score': 0.0011608409695327282},
#   {'label': 'surprise', 'score': 0.0010723872110247612}]]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise"]

def get_top_mean_emotion(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}

    for prediction in predictions:

        if not isinstance(prediction, list):
            prediction = [prediction]

        score_map = {p["label"]: p["score"] for p in prediction}
        for label in emotion_labels:
            per_emotion_scores[label].append(score_map.get(label, 0.0))

    mean_scores = {label: np.mean(scores) for label, scores in per_emotion_scores.items()}
    return max(mean_scores, key=mean_scores.get)

# %%
isb = []
emotions = []

from tqdm import tqdm

for i in tqdm(range(len(books))):
    isb.append(books["isbn13"][i])
    sentences = [s.strip() for s in books["description"][i].split(".") if s.strip()]
    sentences = sentences[:9]
    predictions = []
    for sentence in sentences:
        res = pipe(sentence)

        if len(res) == 1 and isinstance(res[0], list):
            res = res[0]
        predictions.append(res)

    top_emotion = get_top_mean_emotion(predictions)
    emotions.append(top_emotion)
# Out:
# 100%|██████████| 6586/6586 [12:56<00:00,  8.48it/s]

# %%
emotion_df = pd.DataFrame({"isbn13": isb, "emotion": emotions})

# %%
emotion_df
# Out:
#              isbn13   emotion
# 0     9780687002825      fear
# 1     9780974320620  surprise
# 2     9780974320620  surprise
# 3     9781904271062      fear
# 4     9780743223130  surprise
# ...             ...       ...
# 6581  9780310243878  surprise
# 6582  9781591162025  surprise
# 6583  9780440414001   sadness
# 6584  9780618339556   disgust
# 6585  9780393307009  surprise
#
# [6586 rows x 2 columns]

# %%
books = pd.merge(books, emotion_df, on = "isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780687002825  0687002826
# 1     9780974320620         NaN
# 2     9780974320620         NaN
# 3     9780974320620         NaN
# 4     9780974320620         NaN
# ...             ...         ...
# 7173  9780310243878  0310243874
# 7174  9781591162025  1591162025
# 7175  9780440414001  0440414008
# 7176  9780618339556  0618339558
# 7177  9780393307009  039330700X
#
#                                                   title  \
# 0                                 Exclusion and Embrace
# 1                            Emotional Intelligence 2.0
# 2                            Emotional Intelligence 2.0
# 3                            Emotional Intelligence 2.0
# 4                            Emotional Intelligence 2.0
# ...                                                 ...
# 7173                                  Breach of Promise
# 7174                                 Inuyasha Ani-Manga
# 7175                               See You Around, Sam!
# 7176                         Fergus and the Night-Demon
# 7177  Wonderful Life: The Burgess Shale and the Natu...
#
#                                                subtitle  \
# 0     A Theological Exploration of Identity, Otherne...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7173                                                NaN
# 7174                                                NaN
# 7175                                                NaN
# 7176                               An Irish Ghost Story
# 7177                                                NaN
#
#                                                authors  \
# 0                                        Miroslav Volf
# 1     Travis Bradberry, Jean Greaves, Patrick Lencioni
# 2     Travis Bradberry, Jean Greaves, Patrick Lencioni
# 3     Travis Bradberry, Jean Greaves, Patrick Lencioni
# 4     Travis Bradberry, Jean Greaves, Patrick Lencioni
# ...                                                ...
# 7173                                  James Scott Bell
# 7174                                  Rumiko Takahashi
# 7175                                        Lois Lowry
# 7176                                        Jim Murphy
# 7177                                 Stephen Jay Gould
#
#                    categories  \
# 0                    Religion
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 7173                  Fiction
# 7174  Comics & Graphic Novels
# 7175         Juvenile Fiction
# 7176         Juvenile Fiction
# 7177                  Fiction
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=Cqto7...
# 1     https://images.gr-assets.com/books/1328765863m...
# 2     https://images.gr-assets.com/books/1328765863m...
# 3     https://images.gr-assets.com/books/1328765863m...
# 4     https://images.gr-assets.com/books/1328765863m...
# ...                                                 ...
# 7173  http://books.google.com/books/content?id=RNpBD...
# 7174  http://books.google.com/books/content?id=mf55s...
# 7175  http://books.google.com/books/content?id=-oXbx...
# 7176  http://books.google.com/books/content?id=OKeoo...
# 7177  http://books.google.com/books/content?id=SjpSk...
#
#                                             description  published_year  \
# 0     Life at the end of the twentieth century prese...          1996.0
# 1     "Emotional Intelligence 2.0 succinctly explain...          2003.0
# 2     "Emotional Intelligence 2.0 succinctly explain...          2003.0
# 3     "Emotional Intelligence 2.0 succinctly explain...          2003.0
# 4     "Emotional Intelligence 2.0 succinctly explain...          2003.0
# ...                                                 ...             ...
# 7173  Actor and father Mark Gillen finds out how far...          2004.0
# 7174  A teenage girl travels back in time to medieva...          2004.0
# 7175  Sam Krupnik, mad at his mother because she won...          1998.0
# 7176  On his way to town to have some fun, a lazy bu...          2006.0
# 7177  A study of the Burgess Shale, a sea bed 530 mi...          1990.0
#
#       average_rating  num_pages  ratings_count  missing_description   age  \
# 0               4.27      306.0         1895.0                    0  28.0
# 1               3.81      895.0        53384.0                    0  21.0
# 2               3.81      895.0        53384.0                    0  21.0
# 3               3.81      895.0        53384.0                    0  21.0
# 4               3.81      895.0        53384.0                    0  21.0
# ...              ...        ...            ...                  ...   ...
# 7173            4.00      345.0          358.0                    0  20.0
# 7174            4.36      206.0         5787.0                    0  20.0
# 7175            3.68      128.0          235.0                    0  26.0
# 7176            3.71       32.0           70.0                    0  18.0
# 7177            4.12      352.0         8049.0                    0  34.0
#
#       words_in_description                                 title_and_subtitle  \
# 0                      920  Exclusion and Embrace: A Theological Explorati...
# 1                      681                         Emotional Intelligence 2.0
# 2                      681                         Emotional Intelligence 2.0
# 3                      681                         Emotional Intelligence 2.0
# 4                      681                         Emotional Intelligence 2.0
# ...                    ...                                                ...
# 7173                    25                                  Breach of Promise
# 7174                    26                                 Inuyasha Ani-Manga
# 7175                    25                               See You Around, Sam!
# 7176                    26   Fergus and the Night-Demon: An Irish Ghost Story
# 7177                    25  Wonderful Life: The Burgess Shale and the Natu...
#
#                                      tagged_description   simple_categories  \
# 0     9780687002825: Life at the end of the twentiet...          Nonfiction
# 1     9780974320620: "Emotional Intelligence 2.0 suc...          Nonfiction
# 2     9780974320620: "Emotional Intelligence 2.0 suc...          Nonfiction
# 3     9780974320620: "Emotional Intelligence 2.0 suc...          Nonfiction
# 4     9780974320620: "Emotional Intelligence 2.0 suc...          Nonfiction
# ...                                                 ...                 ...
# 7173  9780310243878: Actor and father Mark Gillen fi...             Fiction
# 7174  9781591162025: A teenage girl travels back in ...             Fiction
# 7175  9780440414001: Sam Krupnik, mad at his mother ...  Children's Fiction
# 7176  9780618339556: On his way to town to have some...  Children's Fiction
# 7177  9780393307009: A study of the Burgess Shale, a...             Fiction
#
#        emotion
# 0         fear
# 1     surprise
# 2     surprise
# 3     surprise
# 4     surprise
# ...        ...
# 7173  surprise
# 7174  surprise
# 7175   sadness
# 7176   disgust
# 7177  surprise
#
# [7178 rows x 19 columns]

# %%
books.to_csv("books_with_emotions.csv", index = False)
